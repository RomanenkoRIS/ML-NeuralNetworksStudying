# %%
import os

import torch
import torchvision
import tqdm
import time
from torch import nn
import torchvision.transforms as tfs
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import MNIST
from torchvision.utils import save_image
from tqdm import trange
from colorama import Fore
from torchsummary import summary


# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 12, 4

# %%
import time
from tqdm import tqdm

# %%
# !pip install tqdm
# Out:
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
def add_noise(inputs):
    noise = torch.randn_like(inputs)*1.2      
    return inputs + noise

# %%
def to_img(x):
    x = 0.5 * (x + 1)
    x = x.clamp(0, 1)
    x = x.view(x.size(0), 1, 28, 28)
    return x

# %%
def show_batch(n):
    im = torchvision.utils.make_grid(n)
    plt.imshow(np.transpose(im.numpy(), (1, 2, 0)))

# %%
data_tfs_norm = tfs.Compose([
    tfs.ToTensor(),
    tfs.Normalize((0.1377), (0.3125))])#,
    #AddGaussianNoise(0., 1.0)])


dataset = MNIST('./data', transform=data_tfs_norm, download=True)
dataloader = DataLoader(dataset, batch_size=1000, shuffle=True)

# %%
class ModelAutoencoder(nn.Module):
    def __init__(self, inp_dim, hidden_dim):
        super().__init__()        
        self.encoder = nn.Sequential(
            nn.Linear(inp_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, hidden_dim),
        )
        
        self.decoder = nn.Sequential(
            nn.Linear(hidden_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 256),
            nn.ReLU(),
            nn.Linear(256, inp_dim),
        )

    def forward(self, x):
        shapes = x.shape
        x = x.view(x.size(0), -1)
        return self.decoder(self.encoder(x)).view(*shapes)#(1000, 1, 28, 28)
    
    def encode(self, x):
        x = x.view(x.size(0), -1)
        return self.encoder(x)
    
ModelAutoencoder(28*28, 50)
# Out:
# ModelAutoencoder(
#   (encoder): Sequential(
#     (0): Linear(in_features=784, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=50, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=50, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=784, bias=True)
#   )
# )

# %%
AddGaussianNoise(object)
# Out:
# AddGaussianNoise(mean=<class 'object'>, std=1.0)

# %%
dataiter = iter(dataloader)
images, labels = dataiter.next()

show_batch(images[0:16])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Run model
model = ModelAutoencoder(28*28, 3)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(),
                             lr=1e-2, 
                             weight_decay=1e-5)
num_epochs = 10
results = []
train_losses = []

for epoch in range(num_epochs):
    loss_sum_tr = 0
    pic = 0
   
    for (img, _) in tqdm((dataloader),
                     bar_format="{l_bar}%s{bar}%s{r_bar}" % (Fore.GREEN, Fore.RESET)):
        
        noised_img = add_noise(img)
        loss = criterion(model(noised_img), img)
        loss_sum_tr += loss.item()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()  
    train_losses.append(loss_sum_tr / len(dataloader))
    results.append((epoch, img, output))
  
    # initial
    im_in = torchvision.utils.make_grid(img[0:8])
    plt.imshow(np.transpose(im_in.numpy(), (1, 2, 0)))
    plt.show()
    # noized
    im_n = torchvision.utils.make_grid(noised_img[0:8])
    plt.imshow(np.transpose(im_n.numpy(), (1, 2, 0)))
    plt.show()
    #result
    im_re = torchvision.utils.make_grid(model(noised_img)[0:8])
    plt.imshow(np.transpose(im_re.numpy(), (1, 2, 0)))
    plt.show()
    
    print(f'epoch:{int(epoch+1)}\t train loss:{round(loss_sum_tr / len(dataloader),4)}')
        
plt.plot(train_losses)
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [00:12<00:00,  4.85it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|                                                                                           | 0/60 [00:00<?, ?it/s]
# epoch:1	 train loss:0.698
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [00:12<00:00,  4.85it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
